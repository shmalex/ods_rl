# %%
import json
import glob
import tqdm

# %%
file = list(glob.glob('./experiments/*.json'))

# %%
file = list(glob.glob('./tasks/*.json'))

# %%
file
# Out:
# ['./experiments/2287189634114.json',
#  './experiments/2287198420634.json',
#  './experiments/2287208017163.json',
#  './experiments/2287223764251.json',
#  './experiments/2287236024882.json',
#  './experiments/2287244988261.json',
#  './experiments/2287465267159.json',
#  './experiments/2287475451152.json',
#  './experiments/2287488265106.json',
#  './experiments/2287501931245.json',
#  './experiments/2287512694840.json',
#  './experiments/2287523963825.json',
#  './experiments/2287779104328.json',
#  './experiments/2287789736369.json',
#  './experiments/2287800760379.json',
#  './experiments/2287810209359.json',
#  './experiments/2290186107434.json',
#  './experiments/2290206223614.json',
#  './experiments/2290225173766.json',
#  './experiments/2290248243116.json',
#  './experiments/2290328468478.json',
#  './experiments/2290410650317.json',
#  './experiments/2290491284386.json',
#  './experiments/2290571329061.json',
#  './experiments/2290647408028.json',
# ...

# %%
i = 0
for f in tqdm.tqdm(file):
    try:
        o = json.load(open(f))
        
    except:
        continue
        pass
    if o['finished']:
        o['lr'] = 0.01
#         json.dump(o, open(f,'w'))
        i+=1
# Out:
# 100%|██████████| 162/162 [00:00<00:00, 303.46it/s]

# %%
i
# Out:
# 141

# %%
o['isc']
# Out:
# {'id': '2298818867762',
#  'version': '4',
#  'layers_n': [30, 10, 30],
#  'episode_n': 400,
#  'trajectory_len': 500,
#  'trajectory_n': 100,
#  'q_param': 0.5,
#  'total_elapsed': 21024.598023,
#  'finished': True,
#  'episode_data': [[-212.3853325678701, 50],
#   [-170.05627612741344, 50],
#   [-183.89557169900206, 50],
#   [-150.1904847150644, 50],
#   [-172.1739158053775, 50],
#   [-171.31909616980963, 50],
#   [-182.82829857524862, 50],
#   [-146.63033842340013, 50],
#   [-160.21228845652777, 50],
#   [-164.2383713630154, 50],
#   [-160.76459503644713, 50],
#   [-143.7633055804353, 50],
#   [-147.25996593018846, 50],
#   [-133.57832590690043, 50],
#   [-131.31139158481656, 50],
#   [-138.31935530536492, 50],
#   [-118.10090884045543, 50],
#   [-123.30093413778877, 50],
#   [-121.73849683083165, 50],
#   [-122.34805060742121, 50],
#   [-118.3078013479835, 50],
#   [-119.7160848990713, 50],
#   [-119.50424612642719, 50],
#   [-116.54118866178437, 50],
# ...

# %%
f
# Out:
# './tasks/2308685834395.json'

# %%
len(file)
# Out:
# 354

# %%
i = 0
for f in tqdm.tqdm(file):
    try:
        o = json.load(open(f))
        continue
    except:
        pass
    assert o['lr'] == 0.01
# Out:
# 100%|██████████| 354/354 [00:00<00:00, 1597.95it/s]

# %%
2290410650317
6417427043
2289384530357
